# %%
from alpha_vantage.equity_data import EquityData
import pandas as pd
e = EquityData()
dfs = e.allsheets("ORCL")

# %%
dfs[1].index
# Out:
# Index(['totalAssets', 'totalCurrentAssets',
#        'cashAndCashEquivalentsAtCarryingValue', 'cashAndShortTermInvestments',
#        'inventory', 'currentNetReceivables', 'totalNonCurrentAssets',
#        'propertyPlantEquipment', 'accumulatedDepreciationAmortizationPPE',
#        'intangibleAssets', 'intangibleAssetsExcludingGoodwill', 'goodwill',
#        'investments', 'longTermInvestments', 'shortTermInvestments',
#        'otherCurrentAssets', 'otherNonCurrentAssets', 'totalLiabilities',
#        'totalCurrentLiabilities', 'currentAccountsPayable', 'deferredRevenue',
#        'currentDebt', 'shortTermDebt', 'totalNonCurrentLiabilities',
#        'capitalLeaseObligations', 'longTermDebt', 'currentLongTermDebt',
#        'longTermDebtNoncurrent', 'shortLongTermDebtTotal',
#        'otherCurrentLiabilities', 'otherNonCurrentLiabilities',
#        'totalShareholderEquity', 'treasuryStock', 'retainedEarnings',
#        'commonStock', 'commonStockSharesOutstanding'],
# ...

# %%
keys = pd.concat([pd.Series(sorted(dfs[0].index)), pd.Series(sorted(dfs[1].index)), pd.Series(sorted(dfs[2].index))], axis = 1)
keys.columns = ['income', 'balance', 'cashflow']
keys
# Out:
#                                income                                 balance  \
# 0         comprehensiveIncomeNetOfTax  accumulatedDepreciationAmortizationPPE
# 1                       costOfRevenue                 capitalLeaseObligations
# 2          costofGoodsAndServicesSold   cashAndCashEquivalentsAtCarryingValue
# 3                        depreciation             cashAndShortTermInvestments
# 4         depreciationAndAmortization                             commonStock
# 5                                ebit            commonStockSharesOutstanding
# 6                              ebitda                  currentAccountsPayable
# 7                         grossProfit                             currentDebt
# 8                     incomeBeforeTax                     currentLongTermDebt
# 9                    incomeTaxExpense                   currentNetReceivables
# 10             interestAndDebtExpense                         deferredRevenue
# ...

# %%
e.ratiosCalc(dfs[0].T, dfs[1].T, dfs[2].T)
# Out:
#                   netProfitMargin  grossProfitMargin       ROA       ROE  \
# fiscalDateEnding
# 2023-05-31               0.170217           0.706250  0.063274  7.924511
# 2022-05-31               0.158270           0.567389  0.061456 -1.079904
# 2021-05-31               0.362844           0.712702  0.104846  2.624284
# 2020-05-31               0.274631           0.697404  0.087796  0.839407
# 2019-05-31               0.280540           0.697514  0.101951  0.508745
#
#                   currentRatio  quickRatio  inventoryTurnover
# fiscalDateEnding
# 2023-05-31            0.909658    0.896752          45.516779
# 2022-05-31            1.621291    1.605197          29.788591
# 2021-05-31            2.299578    2.293701          26.359060
# 2020-05-31            3.031395    3.019128          26.637584
# 2019-05-31            2.489855    2.472678          26.828859

# %%
dfs[0].T
# Out:
#                  reportedCurrency  grossProfit totalRevenue costOfRevenue  \
# fiscalDateEnding
# 2023-05-31                    USD  35280000000  49954000000   14674000000
# 2022-05-31                    USD  24080000000  42440000000   15418000000
# 2021-05-31                    USD  27000000000  37884000000   10884000000
# 2020-05-31                    USD  25737000000  36904000000   11167000000
# 2019-05-31                    USD  27556000000  39506000000   11950000000
#
#                  costofGoodsAndServicesSold operatingIncome  \
# fiscalDateEnding
# 2023-05-31                      13564000000     13093000000
# 2022-05-31                       8877000000     10926000000
# 2021-05-31                       7855000000     15213000000
# 2020-05-31                       7938000000     13896000000
# 2019-05-31                       7995000000     13535000000
#
#                  sellingGeneralAndAdministrative researchAndDevelopment  \
# fiscalDateEnding
# ...

# %%
dfs[0]
# Out:
# fiscalDateEnding                    2023-05-31   2022-05-31   2021-05-31  \
# reportedCurrency                           USD          USD          USD
# grossProfit                        35280000000  24080000000  27000000000
# totalRevenue                       49954000000  42440000000  37884000000
# costOfRevenue                      14674000000  15418000000  10884000000
# costofGoodsAndServicesSold         13564000000   8877000000   7855000000
# operatingIncome                    13093000000  10926000000  15213000000
# sellingGeneralAndAdministrative    10412000000   9364000000   8936000000
# researchAndDevelopment              8623000000   7219000000   6527000000
# operatingExpenses                  23297000000  22637000000  17603000000
# investmentIncomeNet                  285000000     94000000    101000000
# netInterestIncome                  -3505000000  -2755000000  -2496000000
# interestIncome                       285000000     94000000    101000000
# ...

# %%
sheets = pd.concat(dfs)
sheets

# %%
dfs[1]

# %%
e.ratios("ORCL")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 e.ratios("ORCL")
#
# AttributeError: 'EquityData' object has no attribute 'ratios'

# %%
e.sheetdata("CASH_FLOW", "ORCL")
# Out:
#   fiscalDateEnding reportedCurrency operatingCashflow  \
# 0       2023-05-31              USD       17165000000
# 1       2022-05-31              USD        9539000000
# 2       2021-05-31              USD       15887000000
# 3       2020-05-31              USD       13139000000
# 4       2019-05-31              USD       14551000000
#
#   paymentsForOperatingActivities proceedsFromOperatingActivities  \
# 0                     7571000000                            None
# 1                     6311000000                            None
# 2                     6669000000                            None
# 3                     6152000000                            None
# 4                     5403000000                            None
#
#   changeInOperatingLiabilities changeInOperatingAssets  \
# 0                    347000000              -166000000
# 1                  -1124000000               863000000
# 2                  -1103000000              -763000000
# ...

# %%
dfs[0]
